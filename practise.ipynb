# %%
class dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

## creating objects
dog1 = dog("Bo",6)
print(dog1.name)
print(dog1.age)
# Out:
# Bo
# 6

# %%
class dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")
